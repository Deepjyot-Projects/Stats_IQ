# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepjyot-Projects/Stats_IQ/blob/main/Stats_IQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ques:
# In a particular area, there are 2 types of weather: sunny and rainy. The following is observed across a couple year period.
#
#
#
#
#
#  The probability of weather staying sunny the following week is 80%.
#
#  The probability of the weather changing from sunny to rainy is 20%.
#
#  The probability of the weather staying rainy from the following week is 70%.
#
#  The probability of weather changing from rainy to sunny over a week is 30%.

# %% [markdown]
# ## Learning
# See the below diag, restaurant serving dishes the next is written using transformation diagram.
#
#
# One imp property:
#
#
# 1. the next day/event probability depends on the current event not on
# all the previous event.
#
# 2. Sum of the outgoing arrows from any state is equal to 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
